# %%
import io

from google.cloud import vision

# %% [markdown]
# #### Load the Image Annotator client

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# #### Analyzing local image

# %% [markdown]
# #### Load an image from your file system
# Source: https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Headphones-Sennheiser-HD555.jpg/320px-Headphones-Sennheiser-HD555.jpg

# %%
with io.open('datasets/headphones.jpg', 'rb') as image_file:
    content = image_file.read()

# %% [markdown]
# #### Create an Image object
# This is initialized with the binary contents of the image we just loaded

# %%
image = vision.types.Image(content=content)

# %% [markdown]
# #### Retrieve all the tags/labels for the image
# We use the label_detection method of our ImageAnnotatorClient. The response is loaded into a response object

# %%
response = client.label_detection(image=image)

# %% [markdown]
# #### View the text labels for the image
# The response contains a field called label_annotations which is a list for all the tags the ImageAnnotatorClient detected for the image

# %%
print('Labels:\n')
for label in response.label_annotations:
  print(label.description)
# Out:
# Labels:
# headphones
# technology
# electronic device
# audio equipment
# audio
# product
# headset

# %% [markdown]
# ### Analyzing remote image
# Here we use several features of the Vision API to analyze remote images.

# %%
image = vision.types.Image()

# %% [markdown]
# #### Detect faces in an image
# Here, we use a stock image with 4 persons

# %%
image.source.image_uri = 'https://images.pexels.com/photos/1059120/pexels-photo-1059120.jpeg?\
cs=srgb&dl=accomplishment-achievement-adult-1059120.jpg&fm=jpg'

# %% [markdown]
# #### Gather the response from the face detection function

# %%
response = client.face_detection(image=image)

# %% [markdown]
# #### Analyze details of each face in the image
# * We are returned the vertices of a bounding polygon for each face in the image
# * For each face, there are "landmarks" representing the fatial features
# * For each face, attributes such as "joy_likelihood", "anger_likelihood" gauge the facial expressions of the individuals

# %%
print('Faces:\n')
for face in response.face_annotations:
    print(face)
# Out:
# Labels:
# bounding_poly {
#   vertices {
#     x: 274
#     y: 847
#   }
#   vertices {
#     x: 658
#     y: 847
#   }
#   vertices {
#     x: 658
#     y: 1293
#   }
#   vertices {
#     x: 274
#     y: 1293
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 316
#     y: 929
#   }
#   vertices {
#     x: 625
#     y: 929
#   }
#   vertices {
#     x: 625
#     y: 1238
#   }
#   vertices {
#     x: 316
#     y: 1238
#   }
# }
# landmarks {
#   type: LEFT_EYE
#   position {
#     x: 430.5929260253906
#     y: 1026.83935546875
#     z: -0.0009079101146198809
#   }
# }
# landmarks {
#   type: RIGHT_EYE
#   position {
#     x: 549.4923095703125
#     y: 1043.66015625
#     z: 19.768447875976562
#   }
# }
# landmarks {
#   type: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 391.7540588378906
#     y: 1002.4783935546875
#     z: 9.176702499389648
#   }
# }
# landmarks {
#   type: RIGHT_OF_LEFT_EYEBROW
#   position {
#     x: 471.19317626953125
#     y: 1004.865234375
#     z: -13.135191917419434
#   }
# }
# landmarks {
#   type: LEFT_OF_RIGHT_EYEBROW
#   position {
#     x: 524.3944702148438
#     y: 1012.7011108398438
#     z: -3.7073476314544678
#   }
# }
# landmarks {
#   type: RIGHT_OF_RIGHT_EYEBROW
#   position {
#     x: 585.80712890625
#     y: 1022.6572265625
#     z: 40.54316329956055
#   }
# }
# landmarks {
#   type: MIDPOINT_BETWEEN_EYES
#   position {
#     x: 495.6666564941406
#     y: 1028.5556640625
#     z: -13.710186958312988
#   }
# }
# landmarks {
#   type: NOSE_TIP
#   position {
#     x: 494.0208435058594
#     y: 1087.7830810546875
#     z: -56.117027282714844
#   }
# }
# landmarks {
#   type: UPPER_LIP
#   position {
#     x: 486.7361145019531
#     y: 1131.6131591796875
#     z: -36.41096496582031
#   }
# }
# landmarks {
#   type: LOWER_LIP
#   position {
#     x: 481.5860900878906
#     y: 1178.064208984375
#     z: -34.357383728027344
#   }
# }
# landmarks {
#   type: MOUTH_LEFT
#   position {
#     x: 421.3788146972656
#     y: 1143.4881591796875
#     z: -12.36032772064209
#   }
# }
# landmarks {
#   type: MOUTH_RIGHT
#   position {
#     x: 536.4066162109375
#     y: 1159.270263671875
#     z: 3.4923834800720215
#   }
# }
# landmarks {
#   type: MOUTH_CENTER
#   position {
#     x: 483.734375
#     y: 1157.8040771484375
#     z: -30.99709701538086
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_RIGHT
#   position {
#     x: 524.3995971679688
#     y: 1108.161376953125
#     z: -7.081198692321777
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_LEFT
#   position {
#     x: 452.77239990234375
#     y: 1099.6708984375
#     z: -19.132553100585938
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_CENTER
#   position {
#     x: 490.0030822753906
#     y: 1111.6953125
#     z: -33.46689224243164
#   }
# }
# landmarks {
#   type: LEFT_EYE_TOP_BOUNDARY
#   position {
#     x: 436.3118896484375
#     y: 1020.7133178710938
#     z: -6.577103614807129
#   }
# }
# landmarks {
#   type: LEFT_EYE_RIGHT_CORNER
#   position {
#     x: 454.396240234375
#     y: 1032.857421875
#     z: 4.050661087036133
#   }
# }
# landmarks {
#   type: LEFT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 429.5633850097656
#     y: 1034.77294921875
#     z: -2.153585433959961
#   }
# }
# landmarks {
#   type: LEFT_EYE_LEFT_CORNER
#   position {
#     x: 407.4881896972656
#     y: 1028.5654296875
#     z: 6.739151477813721
#   }
# }
# landmarks {
#   type: LEFT_EYE_PUPIL
#   position {
#     x: 433.0634460449219
#     y: 1028.814453125
#     z: -3.6175177097320557
#   }
# }
# landmarks {
#   type: RIGHT_EYE_TOP_BOUNDARY
#   position {
#     x: 549.43115234375
#     y: 1034.2783203125
#     z: 12.732664108276367
#   }
# }
# landmarks {
#   type: RIGHT_EYE_RIGHT_CORNER
#   position {
#     x: 569.2035522460938
#     y: 1048.1748046875
#     z: 33.89073944091797
#   }
# }
# landmarks {
#   type: RIGHT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 550.7791137695312
#     y: 1052.1439208984375
#     z: 17.34447479248047
#   }
# }
# landmarks {
#   type: RIGHT_EYE_LEFT_CORNER
#   position {
#     x: 526.9072875976562
#     y: 1043.969970703125
#     z: 15.844051361083984
#   }
# }
# landmarks {
#   type: RIGHT_EYE_PUPIL
#   position {
#     x: 549.158203125
#     y: 1042.862060546875
#     z: 16.040719985961914
#   }
# }
# landmarks {
#   type: LEFT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 435.7021179199219
#     y: 986.5292358398438
#     z: -8.273465156555176
#   }
# }
# landmarks {
#   type: RIGHT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 558.2467041015625
#     y: 1001.1776123046875
#     z: 12.66486644744873
#   }
# }
# landmarks {
#   type: LEFT_EAR_TRAGION
#   position {
#     x: 331.0607604980469
#     y: 1095.362060546875
#     z: 118.60537719726562
#   }
# }
# landmarks {
#   type: RIGHT_EAR_TRAGION
#   position {
#     x: 587.9414672851562
#     y: 1125.9737548828125
#     z: 162.53564453125
#   }
# }
# landmarks {
#   type: FOREHEAD_GLABELLA
#   position {
#     x: 498.3500061035156
#     y: 1004.286376953125
#     z: -12.649263381958008
#   }
# }
# landmarks {
#   type: CHIN_GNATHION
#   position {
#     x: 474.0024108886719
#     y: 1229.7457275390625
#     z: -26.775634765625
#   }
# }
# landmarks {
#   type: CHIN_LEFT_GONION
#   position {
#     x: 345.3896179199219
#     y: 1163.135986328125
#     z: 63.99314498901367
#   }
# }
# landmarks {
#   type: CHIN_RIGHT_GONION
#   position {
#     x: 577.0853271484375
#     y: 1190.6859130859375
#     z: 103.62797546386719
#   }
# }
# roll_angle: 5.29477071762085
# pan_angle: 9.749751091003418
# tilt_angle: 8.662887573242188
# detection_confidence: 0.9999871253967285
# landmarking_confidence: 0.803290069103241
# joy_likelihood: VERY_LIKELY
# sorrow_likelihood: VERY_UNLIKELY
# anger_likelihood: VERY_UNLIKELY
# surprise_likelihood: VERY_UNLIKELY
# under_exposed_likelihood: VERY_UNLIKELY
# blurred_likelihood: VERY_UNLIKELY
# headwear_likelihood: VERY_UNLIKELY
#
# bounding_poly {
#   vertices {
#     x: 1093
#     y: 927
#   }
#   vertices {
#     x: 1490
#     y: 927
#   }
#   vertices {
#     x: 1490
#     y: 1388
#   }
#   vertices {
#     x: 1093
#     y: 1388
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 1161
#     y: 1027
#   }
#   vertices {
#     x: 1459
#     y: 1027
#   }
#   vertices {
#     x: 1459
#     y: 1325
#   }
#   vertices {
#     x: 1161
#     y: 1325
#   }
# }
# landmarks {
#   type: LEFT_EYE
#   position {
#     x: 1270.7618408203125
#     y: 1117.5067138671875
#     z: -0.0008531751809641719
#   }
# }
# landmarks {
#   type: RIGHT_EYE
#   position {
#     x: 1383.39306640625
#     y: 1125.7283935546875
#     z: 35.492862701416016
#   }
# }
# landmarks {
#   type: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 1229.522216796875
#     y: 1093.637939453125
#     z: 2.378873109817505
#   }
# }
# landmarks {
#   type: RIGHT_OF_LEFT_EYEBROW
#   position {
#     x: 1309.360107421875
#     y: 1090.4376220703125
#     z: -8.914456367492676
#   }
# }
# landmarks {
#   type: LEFT_OF_RIGHT_EYEBROW
#   position {
#     x: 1364.540283203125
#     y: 1095.6241455078125
#     z: 8.332924842834473
#   }
# }
# landmarks {
#   type: RIGHT_OF_RIGHT_EYEBROW
#   position {
#     x: 1421.4669189453125
#     y: 1110.12109375
#     z: 62.19125747680664
#   }
# }
# landmarks {
#   type: MIDPOINT_BETWEEN_EYES
#   position {
#     x: 1339.8525390625
#     y: 1115.4049072265625
#     z: -5.439560890197754
#   }
# }
# landmarks {
#   type: NOSE_TIP
#   position {
#     x: 1345.8099365234375
#     y: 1181.4481201171875
#     z: -48.125396728515625
#   }
# }
# landmarks {
#   type: UPPER_LIP
#   position {
#     x: 1333.2545166015625
#     y: 1224.909423828125
#     z: -27.205760955810547
#   }
# }
# landmarks {
#   type: LOWER_LIP
#   position {
#     x: 1329.3048095703125
#     y: 1269.55078125
#     z: -24.615131378173828
#   }
# }
# landmarks {
#   type: MOUTH_LEFT
#   position {
#     x: 1265.56396484375
#     y: 1249.08837890625
#     z: -11.56467342376709
#   }
# }
# landmarks {
#   type: MOUTH_RIGHT
#   position {
#     x: 1370.666259765625
#     y: 1252.4957275390625
#     z: 15.772549629211426
#   }
# }
# landmarks {
#   type: MOUTH_CENTER
#   position {
#     x: 1329.9039306640625
#     y: 1248.57861328125
#     z: -21.399810791015625
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_RIGHT
#   position {
#     x: 1364.3974609375
#     y: 1195.0423583984375
#     z: 5.45760440826416
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_LEFT
#   position {
#     x: 1298.52001953125
#     y: 1189.2823486328125
#     z: -15.033698081970215
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_CENTER
#   position {
#     x: 1335.333740234375
#     y: 1202.630615234375
#     z: -24.405656814575195
#   }
# }
# landmarks {
#   type: LEFT_EYE_TOP_BOUNDARY
#   position {
#     x: 1274.5345458984375
#     y: 1109.507568359375
#     z: -6.369970321655273
#   }
# }
# landmarks {
#   type: LEFT_EYE_RIGHT_CORNER
#   position {
#     x: 1297.729736328125
#     y: 1122.0338134765625
#     z: 7.754400253295898
#   }
# }
# landmarks {
#   type: LEFT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 1269.8863525390625
#     y: 1125.02490234375
#     z: -1.9536553621292114
#   }
# }
# landmarks {
#   type: LEFT_EYE_LEFT_CORNER
#   position {
#     x: 1245.1676025390625
#     y: 1118.7774658203125
#     z: 3.368971109390259
#   }
# }
# landmarks {
#   type: LEFT_EYE_PUPIL
#   position {
#     x: 1270.980224609375
#     y: 1118.041259765625
#     z: -3.379824638366699
#   }
# }
# landmarks {
#   type: RIGHT_EYE_TOP_BOUNDARY
#   position {
#     x: 1387.86572265625
#     y: 1119.0946044921875
#     z: 29.198877334594727
#   }
# }
# landmarks {
#   type: RIGHT_EYE_RIGHT_CORNER
#   position {
#     x: 1404.531005859375
#     y: 1131.8482666015625
#     z: 53.13434982299805
#   }
# }
# landmarks {
#   type: RIGHT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 1384.81689453125
#     y: 1132.0518798828125
#     z: 33.75994110107422
#   }
# }
# landmarks {
#   type: RIGHT_EYE_LEFT_CORNER
#   position {
#     x: 1362.2972412109375
#     y: 1126.03955078125
#     z: 28.891674041748047
#   }
# }
# landmarks {
#   type: RIGHT_EYE_PUPIL
#   position {
#     x: 1387.3187255859375
#     y: 1127.790283203125
#     z: 33.06537628173828
#   }
# }
# landmarks {
#   type: LEFT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 1273.0504150390625
#     y: 1074.5692138671875
#     z: -9.003981590270996
#   }
# }
# landmarks {
#   type: RIGHT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 1396.0777587890625
#     y: 1085.069580078125
#     z: 29.565189361572266
#   }
# }
# landmarks {
#   type: LEFT_EAR_TRAGION
#   position {
#     x: 1152.150390625
#     y: 1187.6400146484375
#     z: 108.66688537597656
#   }
# }
# landmarks {
#   type: RIGHT_EAR_TRAGION
#   position {
#     x: 1409.6998291015625
#     y: 1209.669677734375
#     z: 189.68829345703125
#   }
# }
# landmarks {
#   type: FOREHEAD_GLABELLA
#   position {
#     x: 1338.4364013671875
#     y: 1090.6895751953125
#     z: -4.47093391418457
#   }
# }
# landmarks {
#   type: CHIN_GNATHION
#   position {
#     x: 1322.1715087890625
#     y: 1323.843994140625
#     z: -16.222436904907227
#   }
# }
# landmarks {
#   type: CHIN_LEFT_GONION
#   position {
#     x: 1176.274169921875
#     y: 1258.7147216796875
#     z: 56.35141372680664
#   }
# }
# landmarks {
#   type: CHIN_RIGHT_GONION
#   position {
#     x: 1408.982177734375
#     y: 1278.34716796875
#     z: 129.38839721679688
#   }
# }
# roll_angle: 2.370119571685791
# pan_angle: 17.531972885131836
# tilt_angle: 7.877015113830566
# detection_confidence: 0.9987597465515137
# landmarking_confidence: 0.6836307048797607
# joy_likelihood: VERY_LIKELY
# sorrow_likelihood: VERY_UNLIKELY
# anger_likelihood: VERY_UNLIKELY
# surprise_likelihood: VERY_UNLIKELY
# under_exposed_likelihood: VERY_UNLIKELY
# blurred_likelihood: VERY_UNLIKELY
# headwear_likelihood: VERY_UNLIKELY
#
# bounding_poly {
#   vertices {
#     x: 1733
#     y: 1024
#   }
#   vertices {
#     x: 2098
#     y: 1024
#   }
#   vertices {
#     x: 2098
#     y: 1448
#   }
#   vertices {
#     x: 1733
#     y: 1448
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 1766
#     y: 1116
#   }
#   vertices {
#     x: 2070
#     y: 1116
#   }
#   vertices {
#     x: 2070
#     y: 1420
#   }
#   vertices {
#     x: 1766
#     y: 1420
#   }
# }
# landmarks {
#   type: LEFT_EYE
#   position {
#     x: 1862.24560546875
#     y: 1213.844970703125
#     z: 0.001769188093021512
#   }
# }
# landmarks {
#   type: RIGHT_EYE
#   position {
#     x: 1981.806640625
#     y: 1214.203125
#     z: 5.194483280181885
#   }
# }
# landmarks {
#   type: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 1824.5633544921875
#     y: 1192.35791015625
#     z: 11.25775146484375
#   }
# }
# landmarks {
#   type: RIGHT_OF_LEFT_EYEBROW
#   position {
#     x: 1893.4781494140625
#     y: 1187.7620849609375
#     z: -19.42371940612793
#   }
# }
# landmarks {
#   type: LEFT_OF_RIGHT_EYEBROW
#   position {
#     x: 1948.7484130859375
#     y: 1188.8438720703125
#     z: -17.1505126953125
#   }
# }
# landmarks {
#   type: RIGHT_OF_RIGHT_EYEBROW
#   position {
#     x: 2011.67236328125
#     y: 1190.426025390625
#     z: 17.243572235107422
#   }
# }
# landmarks {
#   type: MIDPOINT_BETWEEN_EYES
#   position {
#     x: 1923.15185546875
#     y: 1208.123046875
#     z: -20.764989852905273
#   }
# }
# landmarks {
#   type: NOSE_TIP
#   position {
#     x: 1924.9404296875
#     y: 1272.2559814453125
#     z: -53.724517822265625
#   }
# }
# landmarks {
#   type: UPPER_LIP
#   position {
#     x: 1922.8697509765625
#     y: 1308.4364013671875
#     z: -29.569223403930664
#   }
# }
# landmarks {
#   type: LOWER_LIP
#   position {
#     x: 1921.968017578125
#     y: 1352.844482421875
#     z: -22.17623519897461
#   }
# }
# landmarks {
#   type: MOUTH_LEFT
#   position {
#     x: 1863.5784912109375
#     y: 1325.62109375
#     z: 1.7432650327682495
#   }
# }
# landmarks {
#   type: MOUTH_RIGHT
#   position {
#     x: 1975.9132080078125
#     y: 1330.712646484375
#     z: 4.791903972625732
#   }
# }
# landmarks {
#   type: MOUTH_CENTER
#   position {
#     x: 1921.856201171875
#     y: 1330.4093017578125
#     z: -21.688304901123047
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_RIGHT
#   position {
#     x: 1957.7718505859375
#     y: 1282.5169677734375
#     z: -9.239349365234375
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_LEFT
#   position {
#     x: 1890.18212890625
#     y: 1279.3455810546875
#     z: -12.84174919128418
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_CENTER
#   position {
#     x: 1924.56689453125
#     y: 1291.34521484375
#     z: -29.3140811920166
#   }
# }
# landmarks {
#   type: LEFT_EYE_TOP_BOUNDARY
#   position {
#     x: 1867.40576171875
#     y: 1207.360595703125
#     z: -7.409916400909424
#   }
# }
# landmarks {
#   type: LEFT_EYE_RIGHT_CORNER
#   position {
#     x: 1886.703857421875
#     y: 1217.9100341796875
#     z: 1.32864511013031
#   }
# }
# landmarks {
#   type: LEFT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 1861.92236328125
#     y: 1221.3880615234375
#     z: -1.1043453216552734
#   }
# }
# landmarks {
#   type: LEFT_EYE_LEFT_CORNER
#   position {
#     x: 1842.9954833984375
#     y: 1216.2752685546875
#     z: 9.4236478805542
#   }
# }
# landmarks {
#   type: LEFT_EYE_PUPIL
#   position {
#     x: 1865.5556640625
#     y: 1214.885986328125
#     z: -3.3623530864715576
#   }
# }
# landmarks {
#   type: RIGHT_EYE_TOP_BOUNDARY
#   position {
#     x: 1975.9752197265625
#     y: 1207.73583984375
#     z: -2.636277437210083
#   }
# }
# landmarks {
#   type: RIGHT_EYE_RIGHT_CORNER
#   position {
#     x: 1997.5460205078125
#     y: 1216.10888671875
#     z: 15.840941429138184
#   }
# }
# landmarks {
#   type: RIGHT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 1982.1673583984375
#     y: 1221.459716796875
#     z: 3.850463390350342
#   }
# }
# landmarks {
#   type: RIGHT_EYE_LEFT_CORNER
#   position {
#     x: 1957.32177734375
#     y: 1218.4564208984375
#     z: 4.303741455078125
#   }
# }
# landmarks {
#   type: RIGHT_EYE_PUPIL
#   position {
#     x: 1976.912353515625
#     y: 1215.3387451171875
#     z: 1.3899004459381104
#   }
# }
# landmarks {
#   type: LEFT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 1862.970947265625
#     y: 1175.6878662109375
#     z: -12.499293327331543
#   }
# }
# landmarks {
#   type: RIGHT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 1980.6002197265625
#     y: 1176.140625
#     z: -7.395529270172119
#   }
# }
# landmarks {
#   type: LEFT_EAR_TRAGION
#   position {
#     x: 1790.2598876953125
#     y: 1269.4722900390625
#     z: 131.29017639160156
#   }
# }
# landmarks {
#   type: RIGHT_EAR_TRAGION
#   position {
#     x: 2038.6405029296875
#     y: 1271.62548828125
#     z: 141.1181640625
#   }
# }
# landmarks {
#   type: FOREHEAD_GLABELLA
#   position {
#     x: 1922.4871826171875
#     y: 1187.223388671875
#     z: -22.713165283203125
#   }
# }
# landmarks {
#   type: CHIN_GNATHION
#   position {
#     x: 1921.0810546875
#     y: 1398.904296875
#     z: -8.829118728637695
#   }
# }
# landmarks {
#   type: CHIN_LEFT_GONION
#   position {
#     x: 1805.805908203125
#     y: 1338.7567138671875
#     z: 85.1191635131836
#   }
# }
# landmarks {
#   type: CHIN_RIGHT_GONION
#   position {
#     x: 2028.135009765625
#     y: 1339.3380126953125
#     z: 94.99494171142578
#   }
# }
# roll_angle: 0.12339428067207336
# pan_angle: 2.524057626724243
# tilt_angle: 1.380283236503601
# detection_confidence: 0.9396436214447021
# landmarking_confidence: 0.7424929738044739
# joy_likelihood: VERY_LIKELY
# sorrow_likelihood: VERY_UNLIKELY
# anger_likelihood: VERY_UNLIKELY
# surprise_likelihood: VERY_UNLIKELY
# under_exposed_likelihood: VERY_UNLIKELY
# blurred_likelihood: VERY_UNLIKELY
# headwear_likelihood: VERY_UNLIKELY
#
# bounding_poly {
#   vertices {
#     x: 2431
#     y: 1124
#   }
#   vertices {
#     x: 2795
#     y: 1124
#   }
#   vertices {
#     x: 2795
#     y: 1547
#   }
#   vertices {
#     x: 2431
#     y: 1547
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 2437
#     y: 1191
#   }
#   vertices {
#     x: 2745
#     y: 1191
#   }
#   vertices {
#     x: 2745
#     y: 1498
#   }
#   vertices {
#     x: 2437
#     y: 1498
#   }
# }
# landmarks {
#   type: LEFT_EYE
#   position {
#     x: 2510.24755859375
#     y: 1322.946044921875
#     z: 0.0013132665771991014
#   }
# }
# landmarks {
#   type: RIGHT_EYE
#   position {
#     x: 2619.661376953125
#     y: 1280.4002685546875
#     z: -32.521507263183594
#   }
# }
# landmarks {
#   type: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 2478.940673828125
#     y: 1311.616455078125
#     z: 25.699352264404297
#   }
# }
# landmarks {
#   type: RIGHT_OF_LEFT_EYEBROW
#   position {
#     x: 2526.199462890625
#     y: 1282.9296875
#     z: -21.39732551574707
#   }
# }
# landmarks {
#   type: LEFT_OF_RIGHT_EYEBROW
#   position {
#     x: 2574.104248046875
#     y: 1265.8741455078125
#     z: -36.14468002319336
#   }
# }
# landmarks {
#   type: RIGHT_OF_RIGHT_EYEBROW
#   position {
#     x: 2643.839111328125
#     y: 1247.8956298828125
#     z: -24.814973831176758
#   }
# }
# landmarks {
#   type: MIDPOINT_BETWEEN_EYES
#   position {
#     x: 2557.44970703125
#     y: 1293.902587890625
#     z: -36.7154655456543
#   }
# }
# landmarks {
#   type: NOSE_TIP
#   position {
#     x: 2561.259033203125
#     y: 1347.143310546875
#     z: -84.39540100097656
#   }
# }
# landmarks {
#   type: UPPER_LIP
#   position {
#     x: 2581.01123046875
#     y: 1387.8433837890625
#     z: -72.05941009521484
#   }
# }
# landmarks {
#   type: LOWER_LIP
#   position {
#     x: 2594.169189453125
#     y: 1424.5289306640625
#     z: -75.52375030517578
#   }
# }
# landmarks {
#   type: MOUTH_LEFT
#   position {
#     x: 2556.948974609375
#     y: 1423.1063232421875
#     z: -37.331295013427734
#   }
# }
# landmarks {
#   type: MOUTH_RIGHT
#   position {
#     x: 2635.15087890625
#     y: 1392.872802734375
#     z: -61.053184509277344
#   }
# }
# landmarks {
#   type: MOUTH_CENTER
#   position {
#     x: 2588.6728515625
#     y: 1405.66845703125
#     z: -69.55062103271484
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_RIGHT
#   position {
#     x: 2612.306884765625
#     y: 1346.6365966796875
#     z: -55.085575103759766
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_LEFT
#   position {
#     x: 2541.1845703125
#     y: 1375.426025390625
#     z: -36.02296447753906
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_CENTER
#   position {
#     x: 2573.565185546875
#     y: 1367.833740234375
#     z: -66.12100982666016
#   }
# }
# landmarks {
#   type: LEFT_EYE_TOP_BOUNDARY
#   position {
#     x: 2510.701171875
#     y: 1312.51171875
#     z: -6.048404216766357
#   }
# }
# landmarks {
#   type: LEFT_EYE_RIGHT_CORNER
#   position {
#     x: 2535.304443359375
#     y: 1314.1729736328125
#     z: -7.19036340713501
#   }
# }
# landmarks {
#   type: LEFT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 2514.259521484375
#     y: 1329.476806640625
#     z: -4.125324726104736
#   }
# }
# landmarks {
#   type: LEFT_EYE_LEFT_CORNER
#   position {
#     x: 2497.94970703125
#     y: 1331.279296875
#     z: 14.478403091430664
#   }
# }
# landmarks {
#   type: LEFT_EYE_PUPIL
#   position {
#     x: 2512.75634765625
#     y: 1320.767333984375
#     z: -3.6067023277282715
#   }
# }
# landmarks {
#   type: RIGHT_EYE_TOP_BOUNDARY
#   position {
#     x: 2609.42333984375
#     y: 1274.3380126953125
#     z: -36.24448776245117
#   }
# }
# landmarks {
#   type: RIGHT_EYE_RIGHT_CORNER
#   position {
#     x: 2637.49072265625
#     y: 1277.1737060546875
#     z: -28.353717803955078
#   }
# }
# landmarks {
#   type: RIGHT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 2620.268310546875
#     y: 1287.6396484375
#     z: -34.65195846557617
#   }
# }
# landmarks {
#   type: RIGHT_EYE_LEFT_CORNER
#   position {
#     x: 2597.975830078125
#     y: 1290.8497314453125
#     z: -25.601804733276367
#   }
# }
# landmarks {
#   type: RIGHT_EYE_PUPIL
#   position {
#     x: 2613.894775390625
#     y: 1281.6207275390625
#     z: -34.683258056640625
#   }
# }
# landmarks {
#   type: LEFT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 2496.083251953125
#     y: 1283.6251220703125
#     z: -0.7124249935150146
#   }
# }
# landmarks {
#   type: RIGHT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 2602.867919921875
#     y: 1242.3514404296875
#     z: -33.49653244018555
#   }
# }
# landmarks {
#   type: LEFT_EAR_TRAGION
#   position {
#     x: 2514.990234375
#     y: 1419.2381591796875
#     z: 127.4194564819336
#   }
# }
# landmarks {
#   type: RIGHT_EAR_TRAGION
#   position {
#     x: 2738.947998046875
#     y: 1332.446533203125
#     z: 58.80342483520508
#   }
# }
# landmarks {
#   type: FOREHEAD_GLABELLA
#   position {
#     x: 2548.264892578125
#     y: 1271.565673828125
#     z: -32.08591079711914
#   }
# }
# landmarks {
#   type: CHIN_GNATHION
#   position {
#     x: 2612.62255859375
#     y: 1472.4521484375
#     z: -75.49581146240234
#   }
# }
# landmarks {
#   type: CHIN_LEFT_GONION
#   position {
#     x: 2529.041259765625
#     y: 1471.3670654296875
#     z: 62.9654541015625
#   }
# }
# landmarks {
#   type: CHIN_RIGHT_GONION
#   position {
#     x: 2731.213623046875
#     y: 1393.1336669921875
#     z: 1.0717288255691528
#   }
# }
# roll_angle: -16.266170501708984
# pan_angle: -16.64545249938965
# tilt_angle: 16.591562271118164
# detection_confidence: 0.9418805837631226
# landmarking_confidence: 0.4037541449069977
# joy_likelihood: VERY_LIKELY
# sorrow_likelihood: VERY_UNLIKELY
# anger_likelihood: VERY_UNLIKELY
# surprise_likelihood: VERY_UNLIKELY
# under_exposed_likelihood: VERY_UNLIKELY
# blurred_likelihood: VERY_UNLIKELY
# headwear_likelihood: VERY_UNLIKELY

# %% [markdown]
# #### Extracting text
# We use one of our own images and use the GCP Vision API to extract the text from it

# %%
image = vision.types.Image()

image.source.image_uri = 'gs://cloud-ml-api/IMG_0203.jpg'

# %% [markdown]
# #### Perform an OCR with the document_text_detection() function

# %%
response = client.document_text_detection(image=image)

# %% [markdown]
# #### Return the text annotations
# This gives all the text captured from the image along with the location of each word in the image

# %%
print('Text:\n')
for text_annotation in response.text_annotations:
    print(text_annotation)
# Out:
# Text:
#
# locale: "en"
# description: "WHEN LOT IS UNATTENDED!\nUSE THE\nHONOR PAY SYSTEM\nFOLLOW INSTRUCTIONS:\n1. Remove Honor Pay envelope from holder\nLocated at HONOR PAY BOX.\n(Red or Yellow Box near Attendant Booth)\n2. Detach Top Half of ticket from\nHonor Pay envelope and\nplace FACE UP on your Dashboard.\nLeave Bottom Half of ticket attached to\nHonor Pay Envelope.\n3. Deposit the Parking Fee in the\nHonor Pay envelope, seal the envelope\nand drop in the HONOR PAY BOX\n(Located near the Attendant Booth )\n4. The Lot Checker matches the ticket number\non your Dashboard with the ticket on the\nHonor Pay envelope that is deposited\nin the HONOR PAY BOX.\nNo Free Parking Anytime!\nENFORCED 24 HOURS\nVehicles without paid tickets\nwill be towed at the Owners/Drivers expense!\nThank You,\n"
# bounding_poly {
#   vertices {
#     x: 237
#     y: 322
#   }
#   vertices {
#     x: 984
#     y: 322
#   }
#   vertices {
#     x: 984
#     y: 1508
#   }
#   vertices {
#     x: 237
#     y: 1508
#   }
# }
#
# description: "WHEN"
# bounding_poly {
#   vertices {
#     x: 241
#     y: 326
#   }
#   vertices {
#     x: 388
#     y: 325
#   }
#   vertices {
#     x: 388
#     y: 388
#   }
#   vertices {
#     x: 241
#     y: 389
#   }
# }
#
# description: "LOT"
# bounding_poly {
#   vertices {
#     x: 413
#     y: 325
#   }
#   vertices {
#     x: 512
#     y: 324
#   }
#   vertices {
#     x: 512
#     y: 387
#   }
#   vertices {
#     x: 413
#     y: 388
#   }
# }
#
# description: "IS"
# bounding_poly {
#   vertices {
#     x: 534
#     y: 324
#   }
#   vertices {
#     x: 568
#     y: 324
#   }
#   vertices {
#     x: 568
#     y: 387
#   }
#   vertices {
#     x: 534
#     y: 387
#   }
# }
#
# description: "UNATTENDED"
# bounding_poly {
#   vertices {
#     x: 590
#     y: 324
#   }
#   vertices {
#     x: 925
#     y: 322
#   }
#   vertices {
#     x: 925
#     y: 385
#   }
#   vertices {
#     x: 590
#     y: 387
#   }
# }
#
# description: "!"
# bounding_poly {
#   vertices {
#     x: 935
#     y: 322
#   }
#   vertices {
#     x: 953
#     y: 322
#   }
#   vertices {
#     x: 953
#     y: 385
#   }
#   vertices {
#     x: 935
#     y: 385
#   }
# }
#
# description: "USE"
# bounding_poly {
#   vertices {
#     x: 457
#     y: 395
#   }
#   vertices {
#     x: 577
#     y: 394
#   }
#   vertices {
#     x: 577
#     y: 426
#   }
#   vertices {
#     x: 457
#     y: 427
#   }
# }
#
# description: "THE"
# bounding_poly {
#   vertices {
#     x: 613
#     y: 394
#   }
#   vertices {
#     x: 724
#     y: 393
#   }
#   vertices {
#     x: 724
#     y: 425
#   }
#   vertices {
#     x: 613
#     y: 426
#   }
# }
#
# description: "HONOR"
# bounding_poly {
#   vertices {
#     x: 267
#     y: 427
#   }
#   vertices {
#     x: 499
#     y: 425
#   }
#   vertices {
#     x: 499
#     y: 499
#   }
#   vertices {
#     x: 268
#     y: 501
#   }
# }
#
# description: "PAY"
# bounding_poly {
#   vertices {
#     x: 522
#     y: 426
#   }
#   vertices {
#     x: 649
#     y: 425
#   }
#   vertices {
#     x: 650
#     y: 499
#   }
#   vertices {
#     x: 523
#     y: 500
#   }
# }
#
# description: "SYSTEM"
# bounding_poly {
#   vertices {
#     x: 675
#     y: 424
#   }
#   vertices {
#     x: 893
#     y: 423
#   }
#   vertices {
#     x: 893
#     y: 497
#   }
#   vertices {
#     x: 676
#     y: 498
#   }
# }
#
# description: "FOLLOW"
# bounding_poly {
#   vertices {
#     x: 338
#     y: 526
#   }
#   vertices {
#     x: 495
#     y: 525
#   }
#   vertices {
#     x: 495
#     y: 572
#   }
#   vertices {
#     x: 338
#     y: 573
#   }
# }
#
# description: "INSTRUCTIONS"
# bounding_poly {
#   vertices {
#     x: 527
#     y: 524
#   }
#   vertices {
#     x: 834
#     y: 522
#   }
#   vertices {
#     x: 834
#     y: 569
#   }
#   vertices {
#     x: 527
#     y: 571
#   }
# }
#
# description: ":"
# bounding_poly {
#   vertices {
#     x: 840
#     y: 522
#   }
#   vertices {
#     x: 853
#     y: 522
#   }
#   vertices {
#     x: 853
#     y: 569
#   }
#   vertices {
#     x: 840
#     y: 569
#   }
# }
#
# description: "1"
# bounding_poly {
#   vertices {
#     x: 240
#     y: 586
#   }
#   vertices {
#     x: 251
#     y: 586
#   }
#   vertices {
#     x: 251
#     y: 628
#   }
#   vertices {
#     x: 240
#     y: 628
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 249
#     y: 586
#   }
#   vertices {
#     x: 260
#     y: 586
#   }
#   vertices {
#     x: 260
#     y: 628
#   }
#   vertices {
#     x: 249
#     y: 628
#   }
# }
#
# description: "Remove"
# bounding_poly {
#   vertices {
#     x: 272
#     y: 586
#   }
#   vertices {
#     x: 399
#     y: 585
#   }
#   vertices {
#     x: 399
#     y: 627
#   }
#   vertices {
#     x: 272
#     y: 628
#   }
# }
#
# description: "Honor"
# bounding_poly {
#   vertices {
#     x: 412
#     y: 585
#   }
#   vertices {
#     x: 515
#     y: 584
#   }
#   vertices {
#     x: 515
#     y: 626
#   }
#   vertices {
#     x: 412
#     y: 627
#   }
# }
#
# description: "Pay"
# bounding_poly {
#   vertices {
#     x: 526
#     y: 585
#   }
#   vertices {
#     x: 580
#     y: 585
#   }
#   vertices {
#     x: 580
#     y: 627
#   }
#   vertices {
#     x: 526
#     y: 627
#   }
# }
#
# description: "envelope"
# bounding_poly {
#   vertices {
#     x: 602
#     y: 584
#   }
#   vertices {
#     x: 745
#     y: 583
#   }
#   vertices {
#     x: 745
#     y: 625
#   }
#   vertices {
#     x: 602
#     y: 626
#   }
# }
#
# description: "from"
# bounding_poly {
#   vertices {
#     x: 761
#     y: 583
#   }
#   vertices {
#     x: 820
#     y: 583
#   }
#   vertices {
#     x: 820
#     y: 625
#   }
#   vertices {
#     x: 761
#     y: 625
#   }
# }
#
# description: "holder"
# bounding_poly {
#   vertices {
#     x: 848
#     y: 582
#   }
#   vertices {
#     x: 952
#     y: 581
#   }
#   vertices {
#     x: 952
#     y: 623
#   }
#   vertices {
#     x: 848
#     y: 624
#   }
# }
#
# description: "Located"
# bounding_poly {
#   vertices {
#     x: 361
#     y: 630
#   }
#   vertices {
#     x: 489
#     y: 629
#   }
#   vertices {
#     x: 489
#     y: 669
#   }
#   vertices {
#     x: 361
#     y: 670
#   }
# }
#
# description: "at"
# bounding_poly {
#   vertices {
#     x: 500
#     y: 629
#   }
#   vertices {
#     x: 538
#     y: 629
#   }
#   vertices {
#     x: 538
#     y: 669
#   }
#   vertices {
#     x: 500
#     y: 669
#   }
# }
#
# description: "HONOR"
# bounding_poly {
#   vertices {
#     x: 543
#     y: 628
#   }
#   vertices {
#     x: 666
#     y: 627
#   }
#   vertices {
#     x: 666
#     y: 667
#   }
#   vertices {
#     x: 543
#     y: 668
#   }
# }
#
# description: "PAY"
# bounding_poly {
#   vertices {
#     x: 681
#     y: 627
#   }
#   vertices {
#     x: 739
#     y: 627
#   }
#   vertices {
#     x: 739
#     y: 667
#   }
#   vertices {
#     x: 681
#     y: 667
#   }
# }
#
# description: "BOX"
# bounding_poly {
#   vertices {
#     x: 754
#     y: 627
#   }
#   vertices {
#     x: 818
#     y: 627
#   }
#   vertices {
#     x: 818
#     y: 667
#   }
#   vertices {
#     x: 754
#     y: 667
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 819
#     y: 627
#   }
#   vertices {
#     x: 830
#     y: 627
#   }
#   vertices {
#     x: 830
#     y: 667
#   }
#   vertices {
#     x: 819
#     y: 667
#   }
# }
#
# description: "("
# bounding_poly {
#   vertices {
#     x: 296
#     y: 674
#   }
#   vertices {
#     x: 307
#     y: 674
#   }
#   vertices {
#     x: 308
#     y: 714
#   }
#   vertices {
#     x: 297
#     y: 714
#   }
# }
#
# description: "Red"
# bounding_poly {
#   vertices {
#     x: 310
#     y: 673
#   }
#   vertices {
#     x: 361
#     y: 672
#   }
#   vertices {
#     x: 362
#     y: 713
#   }
#   vertices {
#     x: 311
#     y: 714
#   }
# }
#
# description: "or"
# bounding_poly {
#   vertices {
#     x: 373
#     y: 673
#   }
#   vertices {
#     x: 402
#     y: 673
#   }
#   vertices {
#     x: 403
#     y: 713
#   }
#   vertices {
#     x: 374
#     y: 713
#   }
# }
#
# description: "Yellow"
# bounding_poly {
#   vertices {
#     x: 414
#     y: 672
#   }
#   vertices {
#     x: 498
#     y: 671
#   }
#   vertices {
#     x: 499
#     y: 711
#   }
#   vertices {
#     x: 415
#     y: 712
#   }
# }
#
# description: "Box"
# bounding_poly {
#   vertices {
#     x: 515
#     y: 671
#   }
#   vertices {
#     x: 566
#     y: 670
#   }
#   vertices {
#     x: 567
#     y: 710
#   }
#   vertices {
#     x: 516
#     y: 711
#   }
# }
#
# description: "near"
# bounding_poly {
#   vertices {
#     x: 576
#     y: 670
#   }
#   vertices {
#     x: 639
#     y: 669
#   }
#   vertices {
#     x: 640
#     y: 709
#   }
#   vertices {
#     x: 577
#     y: 710
#   }
# }
#
# description: "Attendant"
# bounding_poly {
#   vertices {
#     x: 651
#     y: 669
#   }
#   vertices {
#     x: 791
#     y: 667
#   }
#   vertices {
#     x: 792
#     y: 708
#   }
#   vertices {
#     x: 652
#     y: 710
#   }
# }
#
# description: "Booth"
# bounding_poly {
#   vertices {
#     x: 803
#     y: 667
#   }
#   vertices {
#     x: 876
#     y: 666
#   }
#   vertices {
#     x: 877
#     y: 707
#   }
#   vertices {
#     x: 804
#     y: 708
#   }
# }
#
# description: ")"
# bounding_poly {
#   vertices {
#     x: 886
#     y: 666
#   }
#   vertices {
#     x: 897
#     y: 666
#   }
#   vertices {
#     x: 898
#     y: 706
#   }
#   vertices {
#     x: 887
#     y: 706
#   }
# }
#
# description: "2"
# bounding_poly {
#   vertices {
#     x: 310
#     y: 724
#   }
#   vertices {
#     x: 321
#     y: 724
#   }
#   vertices {
#     x: 321
#     y: 764
#   }
#   vertices {
#     x: 310
#     y: 764
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 327
#     y: 724
#   }
#   vertices {
#     x: 338
#     y: 724
#   }
#   vertices {
#     x: 338
#     y: 764
#   }
#   vertices {
#     x: 327
#     y: 764
#   }
# }
#
# description: "Detach"
# bounding_poly {
#   vertices {
#     x: 347
#     y: 724
#   }
#   vertices {
#     x: 458
#     y: 723
#   }
#   vertices {
#     x: 458
#     y: 763
#   }
#   vertices {
#     x: 347
#     y: 764
#   }
# }
#
# description: "Top"
# bounding_poly {
#   vertices {
#     x: 478
#     y: 723
#   }
#   vertices {
#     x: 530
#     y: 723
#   }
#   vertices {
#     x: 530
#     y: 763
#   }
#   vertices {
#     x: 478
#     y: 763
#   }
# }
#
# description: "Half"
# bounding_poly {
#   vertices {
#     x: 543
#     y: 722
#   }
#   vertices {
#     x: 612
#     y: 722
#   }
#   vertices {
#     x: 612
#     y: 762
#   }
#   vertices {
#     x: 543
#     y: 762
#   }
# }
#
# description: "of"
# bounding_poly {
#   vertices {
#     x: 625
#     y: 722
#   }
#   vertices {
#     x: 655
#     y: 722
#   }
#   vertices {
#     x: 655
#     y: 762
#   }
#   vertices {
#     x: 625
#     y: 762
#   }
# }
#
# description: "ticket"
# bounding_poly {
#   vertices {
#     x: 668
#     y: 722
#   }
#   vertices {
#     x: 753
#     y: 721
#   }
#   vertices {
#     x: 753
#     y: 761
#   }
#   vertices {
#     x: 668
#     y: 762
#   }
# }
#
# description: "from"
# bounding_poly {
#   vertices {
#     x: 765
#     y: 721
#   }
#   vertices {
#     x: 829
#     y: 721
#   }
#   vertices {
#     x: 829
#     y: 761
#   }
#   vertices {
#     x: 765
#     y: 761
#   }
# }
#
# description: "Honor"
# bounding_poly {
#   vertices {
#     x: 388
#     y: 767
#   }
#   vertices {
#     x: 492
#     y: 766
#   }
#   vertices {
#     x: 492
#     y: 801
#   }
#   vertices {
#     x: 388
#     y: 802
#   }
# }
#
# description: "Pay"
# bounding_poly {
#   vertices {
#     x: 503
#     y: 767
#   }
#   vertices {
#     x: 558
#     y: 767
#   }
#   vertices {
#     x: 558
#     y: 802
#   }
#   vertices {
#     x: 503
#     y: 802
#   }
# }
#
# description: "envelope"
# bounding_poly {
#   vertices {
#     x: 571
#     y: 766
#   }
#   vertices {
#     x: 721
#     y: 765
#   }
#   vertices {
#     x: 721
#     y: 800
#   }
#   vertices {
#     x: 571
#     y: 801
#   }
# }
#
# description: "and"
# bounding_poly {
#   vertices {
#     x: 733
#     y: 765
#   }
#   vertices {
#     x: 788
#     y: 765
#   }
#   vertices {
#     x: 788
#     y: 800
#   }
#   vertices {
#     x: 733
#     y: 800
#   }
# }
#
# description: "place"
# bounding_poly {
#   vertices {
#     x: 316
#     y: 806
#   }
#   vertices {
#     x: 399
#     y: 805
#   }
#   vertices {
#     x: 399
#     y: 847
#   }
#   vertices {
#     x: 316
#     y: 848
#   }
# }
#
# description: "FACE"
# bounding_poly {
#   vertices {
#     x: 411
#     y: 805
#   }
#   vertices {
#     x: 491
#     y: 804
#   }
#   vertices {
#     x: 491
#     y: 846
#   }
#   vertices {
#     x: 411
#     y: 847
#   }
# }
#
# description: "UP"
# bounding_poly {
#   vertices {
#     x: 504
#     y: 805
#   }
#   vertices {
#     x: 543
#     y: 805
#   }
#   vertices {
#     x: 543
#     y: 847
#   }
#   vertices {
#     x: 504
#     y: 847
#   }
# }
#
# description: "on"
# bounding_poly {
#   vertices {
#     x: 562
#     y: 804
#   }
#   vertices {
#     x: 592
#     y: 804
#   }
#   vertices {
#     x: 592
#     y: 846
#   }
#   vertices {
#     x: 562
#     y: 846
#   }
# }
#
# description: "your"
# bounding_poly {
#   vertices {
#     x: 613
#     y: 804
#   }
#   vertices {
#     x: 682
#     y: 804
#   }
#   vertices {
#     x: 682
#     y: 846
#   }
#   vertices {
#     x: 613
#     y: 846
#   }
# }
#
# description: "Dashboard"
# bounding_poly {
#   vertices {
#     x: 691
#     y: 803
#   }
#   vertices {
#     x: 867
#     y: 802
#   }
#   vertices {
#     x: 867
#     y: 844
#   }
#   vertices {
#     x: 691
#     y: 845
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 872
#     y: 802
#   }
#   vertices {
#     x: 883
#     y: 802
#   }
#   vertices {
#     x: 883
#     y: 844
#   }
#   vertices {
#     x: 872
#     y: 844
#   }
# }
#
# description: "Leave"
# bounding_poly {
#   vertices {
#     x: 276
#     y: 856
#   }
#   vertices {
#     x: 370
#     y: 855
#   }
#   vertices {
#     x: 370
#     y: 895
#   }
#   vertices {
#     x: 276
#     y: 896
#   }
# }
#
# description: "Bottom"
# bounding_poly {
#   vertices {
#     x: 383
#     y: 855
#   }
#   vertices {
#     x: 485
#     y: 854
#   }
#   vertices {
#     x: 485
#     y: 894
#   }
#   vertices {
#     x: 383
#     y: 895
#   }
# }
#
# description: "Half"
# bounding_poly {
#   vertices {
#     x: 508
#     y: 855
#   }
#   vertices {
#     x: 577
#     y: 855
#   }
#   vertices {
#     x: 577
#     y: 895
#   }
#   vertices {
#     x: 508
#     y: 895
#   }
# }
#
# description: "of"
# bounding_poly {
#   vertices {
#     x: 588
#     y: 854
#   }
#   vertices {
#     x: 626
#     y: 854
#   }
#   vertices {
#     x: 626
#     y: 894
#   }
#   vertices {
#     x: 588
#     y: 894
#   }
# }
#
# description: "ticket"
# bounding_poly {
#   vertices {
#     x: 633
#     y: 854
#   }
#   vertices {
#     x: 722
#     y: 853
#   }
#   vertices {
#     x: 722
#     y: 893
#   }
#   vertices {
#     x: 633
#     y: 894
#   }
# }
#
# description: "attached"
# bounding_poly {
#   vertices {
#     x: 734
#     y: 853
#   }
#   vertices {
#     x: 872
#     y: 852
#   }
#   vertices {
#     x: 872
#     y: 892
#   }
#   vertices {
#     x: 734
#     y: 893
#   }
# }
#
# description: "to"
# bounding_poly {
#   vertices {
#     x: 886
#     y: 852
#   }
#   vertices {
#     x: 909
#     y: 852
#   }
#   vertices {
#     x: 909
#     y: 892
#   }
#   vertices {
#     x: 886
#     y: 892
#   }
# }
#
# description: "Honor"
# bounding_poly {
#   vertices {
#     x: 431
#     y: 899
#   }
#   vertices {
#     x: 529
#     y: 898
#   }
#   vertices {
#     x: 529
#     y: 938
#   }
#   vertices {
#     x: 431
#     y: 939
#   }
# }
#
# description: "Pay"
# bounding_poly {
#   vertices {
#     x: 538
#     y: 898
#   }
#   vertices {
#     x: 595
#     y: 898
#   }
#   vertices {
#     x: 595
#     y: 938
#   }
#   vertices {
#     x: 538
#     y: 938
#   }
# }
#
# description: "Envelope"
# bounding_poly {
#   vertices {
#     x: 610
#     y: 898
#   }
#   vertices {
#     x: 757
#     y: 897
#   }
#   vertices {
#     x: 757
#     y: 937
#   }
#   vertices {
#     x: 610
#     y: 938
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 759
#     y: 897
#   }
#   vertices {
#     x: 770
#     y: 897
#   }
#   vertices {
#     x: 770
#     y: 937
#   }
#   vertices {
#     x: 759
#     y: 937
#   }
# }
#
# description: "3"
# bounding_poly {
#   vertices {
#     x: 337
#     y: 950
#   }
#   vertices {
#     x: 348
#     y: 950
#   }
#   vertices {
#     x: 348
#     y: 992
#   }
#   vertices {
#     x: 337
#     y: 992
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 350
#     y: 950
#   }
#   vertices {
#     x: 361
#     y: 950
#   }
#   vertices {
#     x: 361
#     y: 992
#   }
#   vertices {
#     x: 350
#     y: 992
#   }
# }
#
# description: "Deposit"
# bounding_poly {
#   vertices {
#     x: 377
#     y: 950
#   }
#   vertices {
#     x: 498
#     y: 949
#   }
#   vertices {
#     x: 498
#     y: 991
#   }
#   vertices {
#     x: 377
#     y: 992
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 509
#     y: 949
#   }
#   vertices {
#     x: 558
#     y: 949
#   }
#   vertices {
#     x: 558
#     y: 991
#   }
#   vertices {
#     x: 509
#     y: 991
#   }
# }
#
# description: "Parking"
# bounding_poly {
#   vertices {
#     x: 570
#     y: 948
#   }
#   vertices {
#     x: 691
#     y: 947
#   }
#   vertices {
#     x: 691
#     y: 989
#   }
#   vertices {
#     x: 570
#     y: 990
#   }
# }
#
# description: "Fee"
# bounding_poly {
#   vertices {
#     x: 706
#     y: 947
#   }
#   vertices {
#     x: 760
#     y: 947
#   }
#   vertices {
#     x: 760
#     y: 989
#   }
#   vertices {
#     x: 706
#     y: 989
#   }
# }
#
# description: "in"
# bounding_poly {
#   vertices {
#     x: 773
#     y: 947
#   }
#   vertices {
#     x: 789
#     y: 947
#   }
#   vertices {
#     x: 789
#     y: 989
#   }
#   vertices {
#     x: 773
#     y: 989
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 810
#     y: 947
#   }
#   vertices {
#     x: 865
#     y: 947
#   }
#   vertices {
#     x: 865
#     y: 989
#   }
#   vertices {
#     x: 810
#     y: 989
#   }
# }
#
# description: "Honor"
# bounding_poly {
#   vertices {
#     x: 283
#     y: 990
#   }
#   vertices {
#     x: 382
#     y: 989
#   }
#   vertices {
#     x: 383
#     y: 1028
#   }
#   vertices {
#     x: 284
#     y: 1029
#   }
# }
#
# description: "Pay"
# bounding_poly {
#   vertices {
#     x: 395
#     y: 989
#   }
#   vertices {
#     x: 444
#     y: 988
#   }
#   vertices {
#     x: 444
#     y: 1026
#   }
#   vertices {
#     x: 395
#     y: 1027
#   }
# }
#
# description: "envelope"
# bounding_poly {
#   vertices {
#     x: 463
#     y: 988
#   }
#   vertices {
#     x: 607
#     y: 986
#   }
#   vertices {
#     x: 607
#     y: 1025
#   }
#   vertices {
#     x: 464
#     y: 1027
#   }
# }
#
# description: ","
# bounding_poly {
#   vertices {
#     x: 608
#     y: 987
#   }
#   vertices {
#     x: 618
#     y: 987
#   }
#   vertices {
#     x: 618
#     y: 1025
#   }
#   vertices {
#     x: 608
#     y: 1025
#   }
# }
#
# description: "seal"
# bounding_poly {
#   vertices {
#     x: 631
#     y: 986
#   }
#   vertices {
#     x: 693
#     y: 985
#   }
#   vertices {
#     x: 694
#     y: 1024
#   }
#   vertices {
#     x: 632
#     y: 1025
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 701
#     y: 985
#   }
#   vertices {
#     x: 755
#     y: 984
#   }
#   vertices {
#     x: 755
#     y: 1022
#   }
#   vertices {
#     x: 701
#     y: 1023
#   }
# }
#
# description: "envelope"
# bounding_poly {
#   vertices {
#     x: 765
#     y: 984
#   }
#   vertices {
#     x: 910
#     y: 982
#   }
#   vertices {
#     x: 910
#     y: 1021
#   }
#   vertices {
#     x: 766
#     y: 1023
#   }
# }
#
# description: "and"
# bounding_poly {
#   vertices {
#     x: 337
#     y: 1033
#   }
#   vertices {
#     x: 392
#     y: 1032
#   }
#   vertices {
#     x: 393
#     y: 1068
#   }
#   vertices {
#     x: 338
#     y: 1069
#   }
# }
#
# description: "drop"
# bounding_poly {
#   vertices {
#     x: 409
#     y: 1032
#   }
#   vertices {
#     x: 474
#     y: 1031
#   }
#   vertices {
#     x: 475
#     y: 1066
#   }
#   vertices {
#     x: 410
#     y: 1067
#   }
# }
#
# description: "in"
# bounding_poly {
#   vertices {
#     x: 496
#     y: 1031
#   }
#   vertices {
#     x: 513
#     y: 1031
#   }
#   vertices {
#     x: 514
#     y: 1066
#   }
#   vertices {
#     x: 497
#     y: 1066
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 533
#     y: 1029
#   }
#   vertices {
#     x: 583
#     y: 1028
#   }
#   vertices {
#     x: 584
#     y: 1064
#   }
#   vertices {
#     x: 534
#     y: 1065
#   }
# }
#
# description: "HONOR"
# bounding_poly {
#   vertices {
#     x: 593
#     y: 1029
#   }
#   vertices {
#     x: 711
#     y: 1027
#   }
#   vertices {
#     x: 712
#     y: 1062
#   }
#   vertices {
#     x: 594
#     y: 1064
#   }
# }
#
# description: "PAY"
# bounding_poly {
#   vertices {
#     x: 724
#     y: 1026
#   }
#   vertices {
#     x: 784
#     y: 1025
#   }
#   vertices {
#     x: 785
#     y: 1060
#   }
#   vertices {
#     x: 725
#     y: 1061
#   }
# }
#
# description: "BOX"
# bounding_poly {
#   vertices {
#     x: 798
#     y: 1025
#   }
#   vertices {
#     x: 858
#     y: 1024
#   }
#   vertices {
#     x: 859
#     y: 1060
#   }
#   vertices {
#     x: 799
#     y: 1061
#   }
# }
#
# description: "("
# bounding_poly {
#   vertices {
#     x: 350
#     y: 1076
#   }
#   vertices {
#     x: 358
#     y: 1076
#   }
#   vertices {
#     x: 358
#     y: 1107
#   }
#   vertices {
#     x: 350
#     y: 1107
#   }
# }
#
# description: "Located"
# bounding_poly {
#   vertices {
#     x: 369
#     y: 1075
#   }
#   vertices {
#     x: 468
#     y: 1074
#   }
#   vertices {
#     x: 468
#     y: 1106
#   }
#   vertices {
#     x: 369
#     y: 1107
#   }
# }
#
# description: "near"
# bounding_poly {
#   vertices {
#     x: 481
#     y: 1073
#   }
#   vertices {
#     x: 542
#     y: 1072
#   }
#   vertices {
#     x: 542
#     y: 1104
#   }
#   vertices {
#     x: 481
#     y: 1105
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 550
#     y: 1072
#   }
#   vertices {
#     x: 595
#     y: 1071
#   }
#   vertices {
#     x: 595
#     y: 1102
#   }
#   vertices {
#     x: 550
#     y: 1103
#   }
# }
#
# description: "Attendant"
# bounding_poly {
#   vertices {
#     x: 607
#     y: 1071
#   }
#   vertices {
#     x: 746
#     y: 1069
#   }
#   vertices {
#     x: 746
#     y: 1101
#   }
#   vertices {
#     x: 607
#     y: 1103
#   }
# }
#
# description: "Booth"
# bounding_poly {
#   vertices {
#     x: 754
#     y: 1069
#   }
#   vertices {
#     x: 826
#     y: 1068
#   }
#   vertices {
#     x: 826
#     y: 1100
#   }
#   vertices {
#     x: 754
#     y: 1101
#   }
# }
#
# description: ")"
# bounding_poly {
#   vertices {
#     x: 839
#     y: 1068
#   }
#   vertices {
#     x: 847
#     y: 1068
#   }
#   vertices {
#     x: 847
#     y: 1099
#   }
#   vertices {
#     x: 839
#     y: 1099
#   }
# }
#
# description: "4"
# bounding_poly {
#   vertices {
#     x: 237
#     y: 1123
#   }
#   vertices {
#     x: 247
#     y: 1123
#   }
#   vertices {
#     x: 247
#     y: 1161
#   }
#   vertices {
#     x: 237
#     y: 1161
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 253
#     y: 1123
#   }
#   vertices {
#     x: 263
#     y: 1123
#   }
#   vertices {
#     x: 263
#     y: 1161
#   }
#   vertices {
#     x: 253
#     y: 1161
#   }
# }
#
# description: "The"
# bounding_poly {
#   vertices {
#     x: 278
#     y: 1122
#   }
#   vertices {
#     x: 333
#     y: 1121
#   }
#   vertices {
#     x: 333
#     y: 1160
#   }
#   vertices {
#     x: 278
#     y: 1161
#   }
# }
#
# description: "Lot"
# bounding_poly {
#   vertices {
#     x: 346
#     y: 1122
#   }
#   vertices {
#     x: 395
#     y: 1121
#   }
#   vertices {
#     x: 395
#     y: 1159
#   }
#   vertices {
#     x: 346
#     y: 1160
#   }
# }
#
# description: "Checker"
# bounding_poly {
#   vertices {
#     x: 407
#     y: 1120
#   }
#   vertices {
#     x: 530
#     y: 1118
#   }
#   vertices {
#     x: 530
#     y: 1157
#   }
#   vertices {
#     x: 407
#     y: 1159
#   }
# }
#
# description: "matches"
# bounding_poly {
#   vertices {
#     x: 534
#     y: 1119
#   }
#   vertices {
#     x: 672
#     y: 1117
#   }
#   vertices {
#     x: 672
#     y: 1156
#   }
#   vertices {
#     x: 534
#     y: 1158
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 682
#     y: 1117
#   }
#   vertices {
#     x: 731
#     y: 1116
#   }
#   vertices {
#     x: 731
#     y: 1154
#   }
#   vertices {
#     x: 682
#     y: 1155
#   }
# }
#
# description: "ticket"
# bounding_poly {
#   vertices {
#     x: 745
#     y: 1117
#   }
#   vertices {
#     x: 830
#     y: 1116
#   }
#   vertices {
#     x: 830
#     y: 1154
#   }
#   vertices {
#     x: 745
#     y: 1155
#   }
# }
#
# description: "number"
# bounding_poly {
#   vertices {
#     x: 839
#     y: 1115
#   }
#   vertices {
#     x: 962
#     y: 1113
#   }
#   vertices {
#     x: 962
#     y: 1152
#   }
#   vertices {
#     x: 839
#     y: 1154
#   }
# }
#
# description: "on"
# bounding_poly {
#   vertices {
#     x: 275
#     y: 1168
#   }
#   vertices {
#     x: 303
#     y: 1168
#   }
#   vertices {
#     x: 303
#     y: 1199
#   }
#   vertices {
#     x: 275
#     y: 1199
#   }
# }
#
# description: "your"
# bounding_poly {
#   vertices {
#     x: 321
#     y: 1167
#   }
#   vertices {
#     x: 394
#     y: 1166
#   }
#   vertices {
#     x: 394
#     y: 1198
#   }
#   vertices {
#     x: 321
#     y: 1199
#   }
# }
#
# description: "Dashboard"
# bounding_poly {
#   vertices {
#     x: 403
#     y: 1166
#   }
#   vertices {
#     x: 567
#     y: 1164
#   }
#   vertices {
#     x: 567
#     y: 1195
#   }
#   vertices {
#     x: 403
#     y: 1197
#   }
# }
#
# description: "with"
# bounding_poly {
#   vertices {
#     x: 583
#     y: 1164
#   }
#   vertices {
#     x: 646
#     y: 1163
#   }
#   vertices {
#     x: 646
#     y: 1194
#   }
#   vertices {
#     x: 583
#     y: 1195
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 669
#     y: 1163
#   }
#   vertices {
#     x: 718
#     y: 1162
#   }
#   vertices {
#     x: 718
#     y: 1193
#   }
#   vertices {
#     x: 669
#     y: 1194
#   }
# }
#
# description: "ticket"
# bounding_poly {
#   vertices {
#     x: 729
#     y: 1162
#   }
#   vertices {
#     x: 814
#     y: 1161
#   }
#   vertices {
#     x: 814
#     y: 1192
#   }
#   vertices {
#     x: 729
#     y: 1193
#   }
# }
#
# description: "on"
# bounding_poly {
#   vertices {
#     x: 826
#     y: 1160
#   }
#   vertices {
#     x: 861
#     y: 1160
#   }
#   vertices {
#     x: 861
#     y: 1192
#   }
#   vertices {
#     x: 826
#     y: 1192
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 877
#     y: 1160
#   }
#   vertices {
#     x: 926
#     y: 1159
#   }
#   vertices {
#     x: 926
#     y: 1190
#   }
#   vertices {
#     x: 877
#     y: 1191
#   }
# }
#
# description: "Honor"
# bounding_poly {
#   vertices {
#     x: 304
#     y: 1203
#   }
#   vertices {
#     x: 398
#     y: 1202
#   }
#   vertices {
#     x: 398
#     y: 1238
#   }
#   vertices {
#     x: 304
#     y: 1239
#   }
# }
#
# description: "Pay"
# bounding_poly {
#   vertices {
#     x: 410
#     y: 1202
#   }
#   vertices {
#     x: 464
#     y: 1201
#   }
#   vertices {
#     x: 464
#     y: 1236
#   }
#   vertices {
#     x: 410
#     y: 1237
#   }
# }
#
# description: "envelope"
# bounding_poly {
#   vertices {
#     x: 479
#     y: 1201
#   }
#   vertices {
#     x: 619
#     y: 1199
#   }
#   vertices {
#     x: 619
#     y: 1235
#   }
#   vertices {
#     x: 479
#     y: 1237
#   }
# }
#
# description: "that"
# bounding_poly {
#   vertices {
#     x: 631
#     y: 1199
#   }
#   vertices {
#     x: 697
#     y: 1198
#   }
#   vertices {
#     x: 697
#     y: 1234
#   }
#   vertices {
#     x: 631
#     y: 1235
#   }
# }
#
# description: "is"
# bounding_poly {
#   vertices {
#     x: 707
#     y: 1198
#   }
#   vertices {
#     x: 727
#     y: 1198
#   }
#   vertices {
#     x: 727
#     y: 1233
#   }
#   vertices {
#     x: 707
#     y: 1233
#   }
# }
#
# description: "deposited"
# bounding_poly {
#   vertices {
#     x: 739
#     y: 1198
#   }
#   vertices {
#     x: 892
#     y: 1196
#   }
#   vertices {
#     x: 892
#     y: 1232
#   }
#   vertices {
#     x: 739
#     y: 1234
#   }
# }
#
# description: "in"
# bounding_poly {
#   vertices {
#     x: 413
#     y: 1239
#   }
#   vertices {
#     x: 436
#     y: 1239
#   }
#   vertices {
#     x: 436
#     y: 1281
#   }
#   vertices {
#     x: 413
#     y: 1281
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 456
#     y: 1239
#   }
#   vertices {
#     x: 505
#     y: 1239
#   }
#   vertices {
#     x: 505
#     y: 1281
#   }
#   vertices {
#     x: 456
#     y: 1281
#   }
# }
#
# description: "HONOR"
# bounding_poly {
#   vertices {
#     x: 511
#     y: 1239
#   }
#   vertices {
#     x: 631
#     y: 1238
#   }
#   vertices {
#     x: 631
#     y: 1280
#   }
#   vertices {
#     x: 511
#     y: 1281
#   }
# }
#
# description: "PAY"
# bounding_poly {
#   vertices {
#     x: 642
#     y: 1238
#   }
#   vertices {
#     x: 702
#     y: 1238
#   }
#   vertices {
#     x: 702
#     y: 1280
#   }
#   vertices {
#     x: 642
#     y: 1280
#   }
# }
#
# description: "BOX"
# bounding_poly {
#   vertices {
#     x: 717
#     y: 1237
#   }
#   vertices {
#     x: 776
#     y: 1237
#   }
#   vertices {
#     x: 776
#     y: 1279
#   }
#   vertices {
#     x: 717
#     y: 1279
#   }
# }
#
# description: "."
# bounding_poly {
#   vertices {
#     x: 778
#     y: 1237
#   }
#   vertices {
#     x: 789
#     y: 1237
#   }
#   vertices {
#     x: 789
#     y: 1279
#   }
#   vertices {
#     x: 778
#     y: 1279
#   }
# }
#
# description: "No"
# bounding_poly {
#   vertices {
#     x: 305
#     y: 1290
#   }
#   vertices {
#     x: 370
#     y: 1290
#   }
#   vertices {
#     x: 370
#     y: 1341
#   }
#   vertices {
#     x: 305
#     y: 1341
#   }
# }
#
# description: "Free"
# bounding_poly {
#   vertices {
#     x: 387
#     y: 1289
#   }
#   vertices {
#     x: 481
#     y: 1288
#   }
#   vertices {
#     x: 481
#     y: 1339
#   }
#   vertices {
#     x: 387
#     y: 1340
#   }
# }
#
# description: "Parking"
# bounding_poly {
#   vertices {
#     x: 501
#     y: 1289
#   }
#   vertices {
#     x: 677
#     y: 1288
#   }
#   vertices {
#     x: 677
#     y: 1339
#   }
#   vertices {
#     x: 501
#     y: 1340
#   }
# }
#
# description: "Anytime"
# bounding_poly {
#   vertices {
#     x: 692
#     y: 1287
#   }
#   vertices {
#     x: 890
#     y: 1286
#   }
#   vertices {
#     x: 890
#     y: 1337
#   }
#   vertices {
#     x: 692
#     y: 1338
#   }
# }
#
# description: "!"
# bounding_poly {
#   vertices {
#     x: 890
#     y: 1286
#   }
#   vertices {
#     x: 904
#     y: 1286
#   }
#   vertices {
#     x: 904
#     y: 1337
#   }
#   vertices {
#     x: 890
#     y: 1337
#   }
# }
#
# description: "ENFORCED"
# bounding_poly {
#   vertices {
#     x: 409
#     y: 1363
#   }
#   vertices {
#     x: 583
#     y: 1364
#   }
#   vertices {
#     x: 583
#     y: 1399
#   }
#   vertices {
#     x: 409
#     y: 1398
#   }
# }
#
# description: "24"
# bounding_poly {
#   vertices {
#     x: 601
#     y: 1364
#   }
#   vertices {
#     x: 657
#     y: 1364
#   }
#   vertices {
#     x: 657
#     y: 1399
#   }
#   vertices {
#     x: 601
#     y: 1399
#   }
# }
#
# description: "HOURS"
# bounding_poly {
#   vertices {
#     x: 670
#     y: 1364
#   }
#   vertices {
#     x: 791
#     y: 1364
#   }
#   vertices {
#     x: 791
#     y: 1399
#   }
#   vertices {
#     x: 670
#     y: 1399
#   }
# }
#
# description: "Vehicles"
# bounding_poly {
#   vertices {
#     x: 417
#     y: 1402
#   }
#   vertices {
#     x: 518
#     y: 1402
#   }
#   vertices {
#     x: 518
#     y: 1432
#   }
#   vertices {
#     x: 417
#     y: 1432
#   }
# }
#
# description: "without"
# bounding_poly {
#   vertices {
#     x: 526
#     y: 1403
#   }
#   vertices {
#     x: 630
#     y: 1403
#   }
#   vertices {
#     x: 630
#     y: 1433
#   }
#   vertices {
#     x: 526
#     y: 1433
#   }
# }
#
# description: "paid"
# bounding_poly {
#   vertices {
#     x: 635
#     y: 1404
#   }
#   vertices {
#     x: 689
#     y: 1404
#   }
#   vertices {
#     x: 689
#     y: 1433
#   }
#   vertices {
#     x: 635
#     y: 1433
#   }
# }
#
# description: "tickets"
# bounding_poly {
#   vertices {
#     x: 705
#     y: 1403
#   }
#   vertices {
#     x: 785
#     y: 1403
#   }
#   vertices {
#     x: 785
#     y: 1433
#   }
#   vertices {
#     x: 705
#     y: 1433
#   }
# }
#
# description: "will"
# bounding_poly {
#   vertices {
#     x: 299
#     y: 1431
#   }
#   vertices {
#     x: 350
#     y: 1431
#   }
#   vertices {
#     x: 350
#     y: 1461
#   }
#   vertices {
#     x: 299
#     y: 1461
#   }
# }
#
# description: "be"
# bounding_poly {
#   vertices {
#     x: 357
#     y: 1432
#   }
#   vertices {
#     x: 389
#     y: 1432
#   }
#   vertices {
#     x: 389
#     y: 1461
#   }
#   vertices {
#     x: 357
#     y: 1461
#   }
# }
#
# description: "towed"
# bounding_poly {
#   vertices {
#     x: 399
#     y: 1431
#   }
#   vertices {
#     x: 475
#     y: 1431
#   }
#   vertices {
#     x: 475
#     y: 1461
#   }
#   vertices {
#     x: 399
#     y: 1461
#   }
# }
#
# description: "at"
# bounding_poly {
#   vertices {
#     x: 487
#     y: 1432
#   }
#   vertices {
#     x: 514
#     y: 1432
#   }
#   vertices {
#     x: 514
#     y: 1461
#   }
#   vertices {
#     x: 487
#     y: 1461
#   }
# }
#
# description: "the"
# bounding_poly {
#   vertices {
#     x: 523
#     y: 1432
#   }
#   vertices {
#     x: 560
#     y: 1432
#   }
#   vertices {
#     x: 560
#     y: 1462
#   }
#   vertices {
#     x: 523
#     y: 1462
#   }
# }
#
# description: "Owners"
# bounding_poly {
#   vertices {
#     x: 570
#     y: 1431
#   }
#   vertices {
#     x: 666
#     y: 1431
#   }
#   vertices {
#     x: 666
#     y: 1461
#   }
#   vertices {
#     x: 570
#     y: 1461
#   }
# }
#
# description: "/"
# bounding_poly {
#   vertices {
#     x: 672
#     y: 1433
#   }
#   vertices {
#     x: 680
#     y: 1433
#   }
#   vertices {
#     x: 680
#     y: 1462
#   }
#   vertices {
#     x: 672
#     y: 1462
#   }
# }
#
# description: "Drivers"
# bounding_poly {
#   vertices {
#     x: 685
#     y: 1431
#   }
#   vertices {
#     x: 775
#     y: 1431
#   }
#   vertices {
#     x: 775
#     y: 1461
#   }
#   vertices {
#     x: 685
#     y: 1461
#   }
# }
#
# description: "expense"
# bounding_poly {
#   vertices {
#     x: 786
#     y: 1433
#   }
#   vertices {
#     x: 882
#     y: 1433
#   }
#   vertices {
#     x: 882
#     y: 1462
#   }
#   vertices {
#     x: 786
#     y: 1462
#   }
# }
#
# description: "!"
# bounding_poly {
#   vertices {
#     x: 891
#     y: 1433
#   }
#   vertices {
#     x: 899
#     y: 1433
#   }
#   vertices {
#     x: 899
#     y: 1462
#   }
#   vertices {
#     x: 891
#     y: 1462
#   }
# }
#
# description: "Thank"
# bounding_poly {
#   vertices {
#     x: 782
#     y: 1477
#   }
#   vertices {
#     x: 882
#     y: 1476
#   }
#   vertices {
#     x: 882
#     y: 1507
#   }
#   vertices {
#     x: 782
#     y: 1508
#   }
# }
#
# description: "You"
# bounding_poly {
#   vertices {
#     x: 900
#     y: 1476
#   }
#   vertices {
#     x: 962
#     y: 1476
#   }
#   vertices {
#     x: 962
#     y: 1507
#   }
#   vertices {
#     x: 900
#     y: 1507
#   }
# }
#
# description: ","
# bounding_poly {
#   vertices {
#     x: 976
#     y: 1475
#   }
#   vertices {
#     x: 984
#     y: 1475
#   }
#   vertices {
#     x: 984
#     y: 1506
#   }
#   vertices {
#     x: 976
#     y: 1506
#   }
# }
